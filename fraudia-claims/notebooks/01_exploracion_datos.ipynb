# %% [markdown]
# # 01 - Exploracion de datos
#
# Objetivo: revisar el dataset sintetico de siniestros, validar campos principales y entender senales iniciales de riesgo.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT))

from src.ingestion.load_data import load_claims

df = load_claims(PROJECT_ROOT / 'data/synthetic/siniestros_sinteticos.csv')
df.head()

# %%
df.info()
df.describe(include='all')

# %%
df[['cobertura', 'ciudad', 'beneficiario', 'monto_reclamado']].head(10)

# %% [markdown]
# Hallazgos esperados:
#
# - El dataset es sintetico y no contiene datos personales reales.
# - Las variables de fechas, montos, proveedor, documentos y narrativa alimentan reglas y modelo.
# - El analisis no confirma fraude; solo identifica senales para revision.
